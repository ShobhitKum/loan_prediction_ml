# %%
cd D:\Junk\ML\HouseLoan
# Out:
# D:\Junk\ML\HouseLoan

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
df = pd.read_csv('train.csv')

# %%
df = df.dropna()
df['NetIncome'] = df['ApplicantIncome']+df['CoapplicantIncome']


#x = list(df[['Gender','Married']].groupby(df['Property_Area']))
#x[2][1]

# %%
#l = ['Loan_Status','Property_Area','Married','Gender']
#data = df.groupby(l)
#test = data.aggregate(np.mean)
#a = test['ApplicantIncome']

# %%
#pd.DataFrame({'index':a.index, 'values':a.values})

# %%
a1 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Rural")]
a2 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Urban")]
a3 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Semiurban")]
b1 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Rural")]
b2 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Urban")]
b3 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Semiurban")]
c1 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Rural")]
c2 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Urban")]
c3 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Semiurban")]
d1 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Rural")]
d2 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Urban")]
d3 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='Y') & (df['Property_Area']=="Semiurban")]

# %%
a1['mean_income'] = a1.ApplicantIncome.mean()
a1['mean_loan'] = a1.LoanAmount.mean()
a2['mean_income'] = a2.ApplicantIncome.mean()
a2['mean_loan'] = a2.LoanAmount.mean()
a3['mean_income'] = a3.ApplicantIncome.mean()
a3['mean_loan'] = a3.LoanAmount.mean()
b1['mean_income'] = b1.ApplicantIncome.mean()
b1['mean_loan'] = b1.LoanAmount.mean()
b2['mean_income'] = b2.ApplicantIncome.mean()
b2['mean_loan'] = b2.LoanAmount.mean()
b3['mean_income'] = b3.ApplicantIncome.mean()
b3['mean_loan'] = b3.LoanAmount.mean()
c1['mean_income'] = c1.ApplicantIncome.mean()
c1['mean_loan'] = c1.LoanAmount.mean()
c2['mean_income'] = c2.ApplicantIncome.mean()
c2['mean_loan'] = c2.LoanAmount.mean()
c3['mean_income'] = c3.ApplicantIncome.mean()
c3['mean_loan'] = c3.LoanAmount.mean()
d1['mean_income'] = d1.ApplicantIncome.mean()
d1['mean_loan'] = d1.LoanAmount.mean()
d2['mean_income'] = d2.ApplicantIncome.mean()
d2['mean_loan'] = d2.LoanAmount.mean()
d3['mean_income'] = d3.ApplicantIncome.mean()
d3['mean_loan'] = d3.LoanAmount.mean()
# Out:
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# ...

# %%
a1['NetIncome_mean'] = a1.NetIncome.mean()
a1['mean_loan'] = a1.LoanAmount.mean()
a2['NetIncome_mean'] = a2.NetIncome.mean()
a2['mean_loan'] = a2.LoanAmount.mean()
a3['NetIncome_mean'] = a3.NetIncome.mean()
a3['mean_loan'] = a3.LoanAmount.mean()
b1['NetIncome_mean'] = b1.NetIncome.mean()
b1['mean_loan'] = b1.LoanAmount.mean()
b2['NetIncome_mean'] = b2.NetIncome.mean()
b2['mean_loan'] = b2.LoanAmount.mean()
b3['NetIncome_mean'] = b3.NetIncome.mean()
b3['mean_loan'] = b3.LoanAmount.mean()
c1['NetIncome_mean'] = c1.NetIncome.mean()
c1['mean_loan'] = c1.LoanAmount.mean()
c2['NetIncome_mean'] = c2.NetIncome.mean()
c2['mean_loan'] = c2.LoanAmount.mean()
c3['NetIncome_mean'] = c3.NetIncome.mean()
c3['mean_loan'] = c3.LoanAmount.mean()
d1['NetIncome_mean'] = d1.NetIncome.mean()
d1['mean_loan'] = d1.LoanAmount.mean()
d2['NetIncome_mean'] = d2.NetIncome.mean()
d2['mean_loan'] = d2.LoanAmount.mean()
d3['NetIncome_mean'] = d3.NetIncome.mean()
d3['mean_loan'] = d3.LoanAmount.mean()
# Out:
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# ...

# %%
#df.loc[df.Loan_ID == a1.Loan_ID, ['mean_income']] = a1['mean_income']
#df = pd.merge(df, a1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, a2[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, a3[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, b1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, b2[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, b3[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, c1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, c2[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, c3[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, d1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, d2[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
#df = pd.merge(df, d3[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])

# %%
#df = pd.merge(df, a1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
df['mean_loan']=""
df['mean_income']=""
df['NetIncome_mean']=""
#df['NetIncome'] = df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.loc[df.Loan_ID.isin(a1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a1[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(a2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a2[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(a3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a3[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b1[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b2[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b3[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c1[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c2[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c3[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d1[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d2[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d3[['mean_income', 'mean_loan','NetIncome_mean']]

# %%
a11 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Rural")]
a21 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Urban")]
a31 = df[(df['Gender']=="Male") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Semiurban")]
b11 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Rural")]
b21 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Urban")]
b31 = df[(df['Gender']=="Male") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Semiurban")]
c11 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Rural")]
c21 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Urban")]
c31 = df[(df['Gender']=="Female") & (df['Married']=='No') & (df['Loan_Status']=='N') & (df['Property_Area']=="Semiurban")]
d11 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Rural")]
d21 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Urban")]
d31 = df[(df['Gender']=="Female") & (df['Married']=='Yes') & (df['Loan_Status']=='N') & (df['Property_Area']=="Semiurban")]

# %%
a11['mean_income']=a1.mean_income.max()
a11['mean_loan']=a1.mean_loan.max()
a11['NetIncome_mean']=a1.NetIncome_mean.max()

a21['mean_income']=a2.mean_income.max()
a21['mean_loan']=a2.mean_loan.max()
a21['NetIncome_mean']=a2.NetIncome_mean.max()

a31['mean_income']=a3.mean_income.max()
a31['mean_loan']=a3.mean_loan.max()
a31['NetIncome_mean']=a3.NetIncome_mean.max()


b11['mean_income']=b1.mean_income.max()
b11['mean_loan']=b1.mean_loan.max()
b11['NetIncome_mean']=b1.NetIncome_mean.max()


b21['mean_income']=b2.mean_income.max()
b21['mean_loan']=b2.mean_loan.max()
b21['NetIncome_mean']=b2.NetIncome_mean.max()


b31['mean_income']=b3.mean_income.max()
b31['mean_loan']=b3.mean_loan.max()
b31['NetIncome_mean']=b3.NetIncome_mean.max()


c11['mean_income']=c1.mean_income.max()
c11['mean_loan']=c1.mean_loan.max()
c11['NetIncome_mean']=c1.NetIncome_mean.max()

c21['mean_income']=c2.mean_income.max()
c21['mean_loan']=c2.mean_loan.max()
c21['NetIncome_mean']=c2.NetIncome_mean.max()


c31['mean_income']=c3.mean_income.max()
c31['mean_loan']=c3.mean_loan.max()
c31['NetIncome_mean']=c3.NetIncome_mean.max()


d11['mean_income']=d1.mean_income.max()
d11['mean_loan']=d1.mean_loan.max()
d11['NetIncome_mean']=d1.NetIncome_mean.max()


d21['mean_income']=d2.mean_income.max()
d21['mean_loan']=d2.mean_loan.max()
d21['NetIncome_mean']=d2.NetIncome_mean.max()


d31['mean_income']=d3.mean_income.max()
d31['mean_loan']=d3.mean_loan.max()
d31['NetIncome_mean']=d3.NetIncome_mean.max()
# Out:
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# ...

# %%
df.loc[df.Loan_ID.isin(a11.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a11[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(a21.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a21[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(a31.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a31[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b11.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b11[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b21.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b21[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(b31.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b31[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c11.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c11[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c21.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c21[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(c31.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c31[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d11.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d11[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d21.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d21[['mean_income', 'mean_loan','NetIncome_mean']]
df.loc[df.Loan_ID.isin(d31.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d31[['mean_income', 'mean_loan','NetIncome_mean']]

# %%
df['minimun_required_income'] = (df['LoanAmount']/df['mean_loan'])*df['mean_income']
df['deviation_applicant_min_req_inc'] = df['ApplicantIncome'] - df['minimun_required_income']

#x=df.ApplicantIncome>df.mean_income
#df['is_less_than_mean_income'] = x
#df.to_csv('data_mean_app_and_coapp1.csv')

# %%
u=df.ApplicantIncome>df.minimun_required_income
df['ApInc>MinIncReq'] = u
x = df.ApplicantIncome>df.mean_income
df['ApInc>MeanInc'] = x
y = df.NetIncome>df.NetIncome_mean
df['NetInc>NetIncMean']=y
z = df.NetIncome>df.minimun_required_income
df['NetInc>MinReqInc']=z

# %%
df.to_csv('analyzed.csv')

# %%
df['Gender'] = [0 if x=='Male' else 1 if x=='Female' else '0' for x in df['Gender']]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
      
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = le.fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = le.fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
df = MultiColumnLabelEncoder(columns = ['Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']).fit_transform(df)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
#dt = DecisionTreeClassifier(criterion='entropy',min_samples_split=20,random_state=99,max_depth=8)
dt = DecisionTreeClassifier(criterion='entropy',min_samples_split=20,random_state=99,max_depth=10)

clf = svm.SVC(kernel='linear', C = 0.27)

rf = RandomForestClassifier(n_estimators=100) # initialize

# %%
from sklearn.cross_validation import train_test_split

train, test = train_test_split(df, test_size = 0.2)

# %%
predictors = ['ApplicantIncome','Credit_History','Property_Area','Gender','Married','NetIncome','mean_loan','mean_income','NetIncome_mean','minimun_required_income']
target = ['Loan_Status']

# %%
dt.fit(train[predictors], train[target])
#clf.fit(train[predictors], train[target])
#rf.fit(train[predictors2], train[target])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=20, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=99, splitter='best')

# %%
preds=dt.predict(test[predictors])
#preds2 = clf.predict(test[predictors])
#preds3 = rf.predict(test[predictors2])

# %%
    from sklearn import metrics
    def measure_performance(X,y,clf, show_accuracy=True, 
    show_classification_report=True, show_confussion_matrix=True):
        y_pred=clf.predict(X)   
        if show_accuracy:
            print "Accuracy:{0:.3f}".format(
                metrics.accuracy_score(y, y_pred)
            ),"\n"
   
        if show_classification_report:
            print "Classification report"
            print metrics.classification_report(y,y_pred),"\n"
            
        if show_confussion_matrix:
          print "Confussion matrix"
          print metrics.confusion_matrix(y,y_pred),"\n"

# %%
 measure_performance(train[predictors], train[target],dt, show_classification_report=True, show_confussion_matrix=False)
# Out:
# Accuracy:0.865
#
# Classification report
#              precision    recall  f1-score   support
#
#           0       0.78      0.80      0.79       122
#           1       0.90      0.90      0.90       262
#
# avg / total       0.87      0.86      0.86       384

# %%
df1 = pd.read_csv('test.csv')
#df1 = df1.dropna()

# %%
df1['NetIncome'] = df1['ApplicantIncome']+df1['CoapplicantIncome']

# %%
a1 = df1[(df1['Gender']=="Male") & (df1['Married']=='No') & (df1['Property_Area']=="Rural")]
a2 = df1[(df1['Gender']=="Male") & (df1['Married']=='No')  & (df1['Property_Area']=="Urban")]
a3 = df1[(df1['Gender']=="Male") & (df1['Married']=='No')  & (df1['Property_Area']=="Semiurban")]
b1 = df1[(df1['Gender']=="Male") & (df1['Married']=='Yes')  & (df1['Property_Area']=="Rural")]
b2 = df1[(df1['Gender']=="Male") & (df1['Married']=='Yes') & (df1['Property_Area']=="Urban")]
b3 = df1[(df1['Gender']=="Male") & (df1['Married']=='Yes')  & (df1['Property_Area']=="Semiurban")]
c1 = df1[(df1['Gender']=="Female") & (df1['Married']=='No')  & (df1['Property_Area']=="Rural")]
c2 = df1[(df1['Gender']=="Female") & (df1['Married']=='No') & (df1['Property_Area']=="Urban")]
c3 = df1[(df1['Gender']=="Female") & (df1['Married']=='No')  & (df1['Property_Area']=="Semiurban")]
d1 = df1[(df1['Gender']=="Female") & (df1['Married']=='Yes')  & (df1['Property_Area']=="Rural")]
d2 = df1[(df1['Gender']=="Female") & (df1['Married']=='Yes')  & (df1['Property_Area']=="Urban")]
d3 = df1[(df1['Gender']=="Female") & (df1['Married']=='Yes')  & (df1['Property_Area']=="Semiurban")]


a1['mean_income'] = a1.ApplicantIncome.mean()
a1['mean_loan'] = a1.LoanAmount.mean()
a2['mean_income'] = a2.ApplicantIncome.mean()
a2['mean_loan'] = a2.LoanAmount.mean()
a3['mean_income'] = a3.ApplicantIncome.mean()
a3['mean_loan'] = a3.LoanAmount.mean()
b1['mean_income'] = b1.ApplicantIncome.mean()
b1['mean_loan'] = b1.LoanAmount.mean()
b2['mean_income'] = b2.ApplicantIncome.mean()
b2['mean_loan'] = b2.LoanAmount.mean()
b3['mean_income'] = b3.ApplicantIncome.mean()
b3['mean_loan'] = b3.LoanAmount.mean()
c1['mean_income'] = c1.ApplicantIncome.mean()
c1['mean_loan'] = c1.LoanAmount.mean()
c2['mean_income'] = c2.ApplicantIncome.mean()
c2['mean_loan'] = c2.LoanAmount.mean()
c3['mean_income'] = c3.ApplicantIncome.mean()
c3['mean_loan'] = c3.LoanAmount.mean()
d1['mean_income'] = d1.ApplicantIncome.mean()
d1['mean_loan'] = d1.LoanAmount.mean()
d2['mean_income'] = d2.ApplicantIncome.mean()
d2['mean_loan'] = d2.LoanAmount.mean()
d3['mean_income'] = d3.ApplicantIncome.mean()
d3['mean_loan'] = d3.LoanAmount.mean()



a1['NetIncome_mean'] = a1.NetIncome.mean()
a1['mean_loan'] = a1.LoanAmount.mean()
a2['NetIncome_mean'] = a2.NetIncome.mean()
a2['mean_loan'] = a2.LoanAmount.mean()
a3['NetIncome_mean'] = a3.NetIncome.mean()
a3['mean_loan'] = a3.LoanAmount.mean()
b1['NetIncome_mean'] = b1.NetIncome.mean()
b1['mean_loan'] = b1.LoanAmount.mean()
b2['NetIncome_mean'] = b2.NetIncome.mean()
b2['mean_loan'] = b2.LoanAmount.mean()
b3['NetIncome_mean'] = b3.NetIncome.mean()
b3['mean_loan'] = b3.LoanAmount.mean()
c1['NetIncome_mean'] = c1.NetIncome.mean()
c1['mean_loan'] = c1.LoanAmount.mean()
c2['NetIncome_mean'] = c2.NetIncome.mean()
c2['mean_loan'] = c2.LoanAmount.mean()
c3['NetIncome_mean'] = c3.NetIncome.mean()
c3['mean_loan'] = c3.LoanAmount.mean()
d1['NetIncome_mean'] = d1.NetIncome.mean()
d1['mean_loan'] = d1.LoanAmount.mean()
d2['NetIncome_mean'] = d2.NetIncome.mean()
d2['mean_loan'] = d2.LoanAmount.mean()
d3['NetIncome_mean'] = d3.NetIncome.mean()
d3['mean_loan'] = d3.LoanAmount.mean()



#df1 = pd.merge(df1, a1[['Loan_ID','mean_income','mean_loan']], how='left', on=['Loan_ID'])
df1['mean_loan']=""
df1['mean_income']=""
df1['NetIncome_mean']=""
#df1['NetIncome'] = df1['ApplicantIncome']+df1['CoapplicantIncome']
# Out:
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sku276\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
df1.loc[df1.Loan_ID.isin(a1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a1[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(a2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a2[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(a3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = a3[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(b1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b1[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(b2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b2[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(b3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = b3[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(c1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c1[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(c2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c2[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(c3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = c3[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(d1.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d1[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(d2.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d2[['mean_income', 'mean_loan','NetIncome_mean']]
df1.loc[df1.Loan_ID.isin(d3.Loan_ID), ['mean_income', 'mean_loan','NetIncome_mean']] = d3[['mean_income', 'mean_loan','NetIncome_mean']]

# %%
#df1=df1.fillna(0)
#df1.to_csv('yeah.csv')
df1 = pd.read_csv('yeah.csv')

# %%
df1['minimun_required_income'] = (df1['LoanAmount']/df1['mean_loan'])*df1['mean_income']
df1['Gender'] = [0 if x=='Male' else 1 if x=='Female' else '0' for x in df1['Gender']]
df1 = MultiColumnLabelEncoder(columns = ['Married','Dependents','Education','Self_Employed','Property_Area']).fit_transform(df1)

# %%
df1['Loan_Status']=dt.predict(df1[predictors])

# %%
header = ['Loan_ID','Loan_Status']
df1.to_csv('output.csv', columns = header)
output = pd.read_csv('output.csv')
output['Loan_Status'] = ['Y' if x == 1 else 'N' for x in output['Loan_Status']]
output.to_csv('output.csv', columns = header)

# %%
df1 = pd.read_csv('ok.csv')
